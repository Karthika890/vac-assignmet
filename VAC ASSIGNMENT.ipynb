# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = 'https://www.flipkart.com/mobiles/mi~brand/pr?sid=tyy,4io&otracker=nmenu_sub_Electronics_0_Mi'

# %%
allow = requests.get(url)

# %%
print (allow)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup (allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
mobile_name= soup.select("._4rR01T")

# %%
mobile_name
# Out:
# [<div class="_4rR01T">Redmi 9A Sport (Carbon Black, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Metallic Blue, 32 GB)</div>,
#  <div class="_4rR01T">REDMI 10A (Slate Grey, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Coral Green, 32 GB)</div>,
#  <div class="_4rR01T">Xiaomi 11i 5G (Pacific Pearl, 128 GB)</div>,
#  <div class="_4rR01T">REDMI 10A (Charcoal Black, 32 GB)</div>,
#  <div class="_4rR01T">Xiaomi 11i 5G (Stealth Black, 128 GB)</div>,
#  <div class="_4rR01T">Redmi 9A (Nature Green, 32 GB)</div>,
#  <div class="_4rR01T">Xiaomi 11i 5G (Purple Mist, 128 GB)</div>,
#  <div class="_4rR01T">Redmi 9A (SeaBlue, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A (Nature Green, 32 GB)</div>,
#  <div class="_4rR01T">Xiaomi 11i 5G (Stealth Black, 128 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Metallic Blue, 32 GB)</div>,
#  <div class="_4rR01T">Xiaomi 11i 5G (Camo Green, 128 GB)</div>,
#  <div class="_4rR01T">Redmi 9A (Midnight Black, 32 GB)</div>,
# ...

# %%
mobile_list =[]
mobile_link =[]

# %%
for item in mobile_name:
    mobile_list.append(item.text)
    link ="https://www.flipkart.com/"

# %%
mobile_list
# Out:
# ['Redmi 9A Sport (Carbon Black, 32 GB)',
#  'Redmi 9A Sport (Metallic Blue, 32 GB)',
#  'REDMI 10A (Slate Grey, 32 GB)',
#  'Redmi 9A Sport (Coral Green, 32 GB)',
#  'Xiaomi 11i 5G (Pacific Pearl, 128 GB)',
#  'REDMI 10A (Charcoal Black, 32 GB)',
#  'Xiaomi 11i 5G (Stealth Black, 128 GB)',
#  'Redmi 9A (Nature Green, 32 GB)',
#  'Xiaomi 11i 5G (Purple Mist, 128 GB)',
#  'Redmi 9A (SeaBlue, 32 GB)',
#  'Redmi 9A (Nature Green, 32 GB)',
#  'Xiaomi 11i 5G (Stealth Black, 128 GB)',
#  'Redmi 9A Sport (Metallic Blue, 32 GB)',
#  'Xiaomi 11i 5G (Camo Green, 128 GB)',
#  'Redmi 9A (Midnight Black, 32 GB)',
#  'Xiaomi 11i 5G (Purple Mist, 128 GB)',
#  'Redmi Note 11 PRO Plus 5G (Phantom White, 128 GB)',
#  'Redmi Note 11 (Space Black, 128 GB)',
#  'Redmi Note 11 (Space Black, 64 GB)',
#  'REDMI Note 11T 5G (Matte black, 128 GB)',
#  'Xiaomi 11T Pro 5G Hyperphone (Meteorite Black, 256 GB)',
#  'Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)',
#  'REDMI Note 11T 5G (Matte black, 128 GB)',
# ...

# %%
mobile_price =soup.select("._1_WHN1")

# %%
mobile_price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹6,800</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,880</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,988</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,829</div>,
#  <div class="_30jeq3 _1_WHN1">₹24,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹24,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,895</div>,
#  <div class="_30jeq3 _1_WHN1">₹24,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,040</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹26,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,853</div>,
#  <div class="_30jeq3 _1_WHN1">₹24,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,199</div>,
#  <div class="_30jeq3 _1_WHN1">₹26,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹21,489</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,947</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,370</div>,
#  <div class="_30jeq3 _1_WHN1">₹17,000</div>,
#  <div class="_30jeq3 _1_WHN1">₹39,790</div>,
# ...

# %%
price =[]

# %%
for item in mobile_price:
    price.append(item.text)

# %%
price
# Out:
# ['₹6,800',
#  '₹6,880',
#  '₹8,988',
#  '₹6,829',
#  '₹24,999',
#  '₹8,990',
#  '₹24,999',
#  '₹7,895',
#  '₹24,999',
#  '₹7,040',
#  '₹6,990',
#  '₹26,999',
#  '₹7,853',
#  '₹24,999',
#  '₹7,199',
#  '₹26,999',
#  '₹21,489',
#  '₹15,947',
#  '₹14,370',
#  '₹17,000',
#  '₹39,790',
#  '₹25,696',
#  '₹18,888',
#  '₹13,850']

# %%
import pandas as pd

# %%
mobile = pd.DataFrame(mobile_name,columns=["Mobile_name"])

# %%
mobile["price"] = price

# %%
mobile
# Out:
#                                           Mobile_name    price
# 0                Redmi 9A Sport (Carbon Black, 32 GB)   ₹6,800
# 1               Redmi 9A Sport (Metallic Blue, 32 GB)   ₹6,880
# 2                       REDMI 10A (Slate Grey, 32 GB)   ₹8,988
# 3                 Redmi 9A Sport (Coral Green, 32 GB)   ₹6,829
# 4               Xiaomi 11i 5G (Pacific Pearl, 128 GB)  ₹24,999
# 5                   REDMI 10A (Charcoal Black, 32 GB)   ₹8,990
# 6               Xiaomi 11i 5G (Stealth Black, 128 GB)  ₹24,999
# 7                      Redmi 9A (Nature Green, 32 GB)   ₹7,895
# 8                 Xiaomi 11i 5G (Purple Mist, 128 GB)  ₹24,999
# 9                           Redmi 9A (SeaBlue, 32 GB)   ₹7,040
# 10                     Redmi 9A (Nature Green, 32 GB)   ₹6,990
# 11              Xiaomi 11i 5G (Stealth Black, 128 GB)  ₹26,999
# 12              Redmi 9A Sport (Metallic Blue, 32 GB)   ₹7,853
# 13                 Xiaomi 11i 5G (Camo Green, 128 GB)  ₹24,999
# ...

# %%
mobile.to_csv('ASSIGNMENT.csv')
